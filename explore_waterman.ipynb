# %%
import acquire

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_json('data.json')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   repo             150 non-null    object
#  1   language         150 non-null    object
#  2   readme_contents  150 non-null    object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %%
df[df.language == 'Python']
# Out:
#                                                   repo language  \
# 100                           huggingface/transformers   Python
# 101              josephmisiti/awesome-machine-learning   Python
# 102                          scikit-learn/scikit-learn   Python
# 103                              fighting41love/funNLP   Python
# 104                    eriklindernoren/ML-From-Scratch   Python
# 105                                        RasaHQ/rasa   Python
# 106                                       aleju/imgaug   Python
# 107                              gunthercox/ChatterBot   Python
# 108                                      mlflow/mlflow   Python
# 109                                      microsoft/nni   Python
# 110                                 ddbourgin/numpy-ml   Python
# 111                            PySimpleGUI/PySimpleGUI   Python
# 112                       ml-tooling/best-of-ml-python   Python
# 113                               rushter/MLAlgorithms   Python
# ...
